# %%
#%matplotlib notebook

# %%
import os
import requests
import json
from pprint import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# file paths
path_age_65 = ('Cleaned_Data/age_65andover.csv')
path_obesity = ('Cleaned_Data/age_65_obesity.csv')

# %%
# display data, remove unnamed index.
age_65 = pd.read_csv(path_age_65)
age_65 = age_65.rename(columns={'Unnamed: 0': 'Age'})

age_65
# Out:
#     Year  Population
# 0   2000    35069568
# 1   2001    35290291
# 2   2002    35522207
# 3   2003    35863529
# 4   2004    36203319
# 5   2005    36649798
# 6   2006    37164107
# 7   2007    37825711
# 8   2008    38777621
# 9   2009    39623175
# 10  2010    40267984
# 11  2011    39179000
# 12  2012    41507000
# 13  2013    43287000
# 14  2014    44477000
# 15  2015    45994000
# 16  2016    47547000

# %%
# display obesity data

obesity_65 = pd.read_csv(path_obesity)
pop_graph = obesity_65[['Year','Population','Obese Count']]
pop_graph = pop_graph.iloc[11:17,:]
population_graph = pop_graph.set_index('Year')

# %%
# Create variable, and labels for charts

#year = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]
year = [2011, 2012, 2013, 2014, 2015, 2016]
population = [39179000, 41507000, 43287000, 44477000, 45994000, 47547000]
#population = [35069568, 35290291, 35522207, 35863529, 36203319, 36649798, 37164107, 37825711, 38777621, 39623175, 40267984, 39179000, 41507000, 43287000, 44477000, 45994000, 47547000]
obese_count = [9794750, 10791820, 11254620, 12008790, 12878320, 13313160]

# Bar Graph
plt.bar(year, population, color='g', align='center')

plt.xlabel("Year")
plt.ylabel("Population in 10 Millions")
plt.title("65 and Over Population by Year")
# Out:
# Text(0.5, 1.0, '65 and Over Population by Year')

# %%
# Line Graph

population, = plt.plot(year, population, color='g', label="65 and Over Pop.")

plt.xlabel("Year")
plt.ylabel("Population in 10 Millions")
plt.title("65 and Over Population by Year")



population

# %%
#year = [2011, 2012, 2013, 2014, 2015, 2016]
obesity, = plt.plot(year, obese_count, color = 'b', label="Obesity Count")
obesity

# %%
population_graph.plot.line()

# %%
population_graph.plot.bar(figsize=(10,6), rot=0)
plt.ylabel("Population in 10 Millions")
plt.title("Age 65 and Older Population/Obese Population")
plt.set_ylim(0, 50)
plt.savefig("Images/65_Obesity_growth.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-f286b5b44812> in <module>
#       2 plt.ylabel("Population in 10 Millions")
#       3 plt.title("Age 65 and Older Population/Obese Population")
# ----> 4 plt.set_ylim(0, 50)
#       5 plt.savefig("Images/65_Obesity_growth.png")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_ylim'
