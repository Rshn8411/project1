# %%
# Dependencies
import os
import requests
import json
from pprint import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

path_medianincome = ("Resources/MedianIncomeData.csv")

# %%
median_income = pd.read_csv(path_medianincome)
median_income.head()
# Out:
#            State 2018 Median\nincome 2017 Median\nincome 2016 Median\nincome  \
# 0  United States              63,179              61,136              59,039
# 1        Alabama              49,936              50,865              47,221
# 2         Alaska              68,734              77,987              75,723
# 3        Arizona              62,283              59,700              57,100
# 4       Arkansas              49,781              49,751              45,907
#
#   2015 Median\nincome 2014 Median\nincome 2013 Median\nincome  \
# 0              56,516              53,657              53,585
# 1              44,509              42,278              47,320
# 2              75,112              67,629              72,472
# 3              52,248              49,254              52,611
# 4              42,798              44,922              39,376
#
#   2012Median\nincome 2011 Median\nincome 2010 Median\nincome  \
# 0             51,017              50,054              49,276
# ...

# %%
#median_income = median_income.set_index('State')
#del median_income.index.name
median_income
# Out:
#                2018 Median\nincome 2017 Median\nincome 2016 Median\nincome  \
# United States               63,179              61,136              59,039
# Alabama                     49,936              50,865              47,221
# Alaska                      68,734              77,987              75,723
# Arizona                     62,283              59,700              57,100
# Arkansas                    49,781              49,751              45,907
# California                  70,489              70,038              66,637
# Colorado                    73,034              74,984              70,566
# Connecticut                 72,812              74,304              75,923
# Delaware                    65,012              64,961              58,046
# D.C.                        85,750              81,282              70,982
# Florida                     54,644              53,086              51,176
# ...
