# %%
import os
import requests
import json
from pprint import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#file paths
path_age_2000s = ('Resources/age_distribution_2000s.csv')
path_age_2011 = ('Resources/age_distribution_2011.csv')
path_age_2012 = ('Resources/age_distribution_2012.csv')
path_age_2013 = ('Resources/age_distribution_2013.csv')
path_age_2014 = ('Resources/age_distribution_2014.csv')
path_age_2015 = ('Resources/age_distribution_2015.csv')
path_age_2016 = ('Resources/age_distribution_2016.csv')

# %%
age_dist_2000s = pd.read_csv(path_age_2000s)
age_dist_2000s
# Out:
#             Unnamed: 0         2000         2001         2002         2003  \
# 0                Total  282,162,411  284,968,955  287,625,193  290,107,933
# 1        Under 5 years   19,178,293   19,298,217   19,429,192   19,592,446
# 2         5 to 9 years   20,463,852   20,173,362   19,872,417   19,620,851
# 3       10 to 14 years   20,637,696   20,978,678   21,261,421   21,415,353
# 4       15 to 19 years   20,294,955   20,456,284   20,610,370   20,797,166
# 5       20 to 24 years   19,116,667   19,757,286   20,243,765   20,591,688
# 6       25 to 29 years   19,280,263   18,819,347   18,691,340   18,771,585
# 7       30 to 34 years   20,524,234   20,652,175   20,658,306   20,472,210
# 8       35 to 39 years   22,650,852   22,235,918   21,751,218   21,264,159
# 9       40 to 44 years   22,517,991   22,815,834   22,889,431   22,890,047
# 10      45 to 49 years   20,219,527   20,698,983   21,252,288   21,722,676
# ...
