# %%
# Dependencies
import os
import requests
import json
from pprint import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path_2008 = ('Resources/2008data.csv')
path_2011 = ('Resources/2011data.csv')
path_2014 = ('Resources/2014data.csv')
path_2017 = ('Resources/2017data.csv')
    
medicare_data_2008 = pd.read_csv(path_2008)
medicare_data_2011 = pd.read_csv(path_2011)
medicare_data_2014 = pd.read_csv(path_2014)
medicare_data_2017 = pd.read_csv(path_2017)

medicare_data_2017.head()
# Out:
#   Unnamed: 0      Unnamed: 1                  Unnamed: 2  \
# 0      State          County  State and County FIPS Code
# 1         Na  NATIONAL TOTAL                         NaN
# 2         AK     STATE TOTAL                         NaN
# 3         AK  Aleutians East                       02013
# 4         AK  Aleutians West                       02016
#
#   Beneficiary Demographic Characteristics         Unnamed: 4  \
# 0    Beneficiaries with Part A and Part B  FFS Beneficiaries
# 1                              54,577,161         33,725,823
# 2                                  82,458             80,901
# 3                                       *                116
# 4                                       *                140
#
#          Unnamed: 5             Unnamed: 6   Unnamed: 7      Unnamed: 8  \
# 0  MA Beneficiaries  MA Participation Rate  Average Age  Percent Female
# 1        20,851,338                38.21 %           72         54.77 %
# 2             1,557                 1.89 %           70         50.51 %
# 3                 *                      *           72         44.83 %
# 4                 *                      *           71         47.14 %
#
#      Unnamed: 9  ...                                       Unnamed: 235  \
# 0  Percent Male  ...  PQI11 Bacterial Pneumonia Admission Rate (age ...
# 1       45.23 %  ...                                                407
# 2       49.49 %  ...                                                192
# 3       55.17 %  ...
# 4       52.86 %  ...
#
#                                         Unnamed: 236  \
# 0  PQI11 Bacterial Pneumonia Admission Rate (age ...
# 1                                                286
# 2                                                239
# 3
# 4
#
#                                         Unnamed: 237  \
# 0  PQI11 Bacterial Pneumonia Admission Rate (age ...
# 1                                                909
# 2                                                944
# 3
# 4
#
#                           Unnamed: 238                          Unnamed: 239  \
# 0  PQI12 UTI Admission Rate (age < 65)  PQI12 UTI Admission Rate (age 65-74)
# 1                                  306                                   236
# 2                                  122                                   105
# 3
# 4
#
#                          Unnamed: 240  \
# 0  PQI12 UTI Admission Rate (age 75+)
# 1                                 997
# 2                                 459
# 3
# 4
#
#                                         Unnamed: 241  \
# 0  PQI15 Asthma in Younger Adults Admission Rate ...
# 1                                                169
# 2                                                  *
# 3
# 4
#
#                                         Unnamed: 242  \
# 0  PQI16 Lower Extremity Amputation Admission Rat...
# 1                                                219
# 2                                                183
# 3
# 4
#
#                                         Unnamed: 243  \
# 0  PQI16 Lower Extremity Amputation Admission Rat...
# 1                                                 66
# 2                                                 27
# 3
# 4
#
#                                         Unnamed: 244
# 0  PQI16 Lower Extremity Amputation Admission Rat...
# 1                                                 57
# 2                                                 43
# 3
# 4
#
# [5 rows x 245 columns]
