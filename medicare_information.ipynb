# %%
# Dependencies
import os
import requests
import json
from pprint import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path_2008 = ('Resources/2008data.csv')
path_2011 = ('Resources/2011data.csv')
path_2014 = ('Resources/2014data.csv')
path_2017 = ('Resources/2017data.csv')
    
medicare_data_2008 = pd.read_csv(path_2008)
medicare_data_2011 = pd.read_csv(path_2011)
medicare_data_2014 = pd.read_csv(path_2014)
medicare_data_2017 = pd.read_csv(path_2017)

medicare_data_2017.columns
# Out:
# Index(['State', 'County', 'State and County FIPS Code',
#        'Beneficiaries with Part A and Part B', 'FFS Beneficiaries',
#        'MA Beneficiaries', 'MA Participation Rate', 'Average Age',
#        'Percent Female', 'Percent Male',
#        ...
#        'PQI11 Bacterial Pneumonia Admission Rate (age < 65)',
#        'PQI11 Bacterial Pneumonia Admission Rate (age 65-74)',
#        'PQI11 Bacterial Pneumonia Admission Rate (age 75+)',
#        'PQI12 UTI Admission Rate (age < 65)',
#        'PQI12 UTI Admission Rate (age 65-74)',
#        'PQI12 UTI Admission Rate (age 75+)',
#        'PQI15 Asthma in Younger Adults Admission Rate (age < 40)',
#        'PQI16 Lower Extremity Amputation Admission Rate (age < 65)',
#        'PQI16 Lower Extremity Amputation Admission Rate (age 65-74)',
#        'PQI16 Lower Extremity Amputation Admission Rate (age 75+)'],
#       dtype='object', length=245)

# %%
medicare_data_2011_clean = medicare_data_2011.iloc(:,[1:26])
# Out:
#   File "<ipython-input-8-6cf944964f6e>", line 1
#     medicare_data_2011_clean = medicare_data_2011.iloc(:,[1:26])
#                                                        ^
# SyntaxError: invalid syntax

# %%
medicare_data_2011_clean.head()
# Out:
#   State          County  State and County FIPS Code  \
# 1    AK     STATE TOTAL                         NaN
# 2    AK  Aleutians East                      2013.0
# 3    AK  Aleutians West                      2016.0
# 4    AK       Anchorage                      2020.0
# 5    AK          Bethel                      2050.0
#
#   Beneficiaries with Part A and Part B FFS Beneficiaries MA Beneficiaries  \
# 1                               63,441            62,803              638
# 2                                    *                96                *
# 3                                  111               111                0
# 4                               24,713            24,438              275
# 5                                    *               964                *
#
#   MA Participation Rate Average Age Percent Female Percent Male  ...  \
# 1                 1.01%          70         50.58%       49.42%  ...
# ...

# %%
median_vs_medicare_2008_df = pd.DataFrame(medicare_data_2008)
median_vs_medicare_2011_df = pd.DataFrame(medicare_data_2011)
median_vs_medicare_2014_df = pd.DataFrame(medicare_data_2014)
median_vs_medicare_2017_df = pd.DataFrame(medicare_data_2017)

# %%
median_vs_medicare_2008_df

# %%
median_income = pd.read_csv("Resources/MedianIncomeData.csv")

# %%
median_income.head(20)
# Out:
#             State 2018 Median\r\nincome 2017 Median\r\nincome  \
# 0   United States                63,179                61,136
# 1         Alabama                49,936                50,865
# 2          Alaska                68,734                77,987
# 3         Arizona                62,283                59,700
# 4        Arkansas                49,781                49,751
# 5      California                70,489                70,038
# 6        Colorado                73,034                74,984
# 7     Connecticut                72,812                74,304
# 8        Delaware                65,012                64,961
# 9            D.C.                85,750                81,282
# 10        Florida                54,644                53,086
# 11        Georgia                55,821                57,985
# 12         Hawaii                80,108                73,599
# 13          Idaho                58,728                59,497
# ...
