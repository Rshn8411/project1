# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
healthcomp_csv = pd.read_csv('Cleaned_Data/health_consumption_expenditures.csv')
total_national = pd.read_csv('Cleaned_Data/total_national_expenditures.csv')
historical = pd.read_csv('Cleaned_Data/historical_healthcare_data_summary.csv')
health_habits = pd.read_csv('Resources/health_habits.csv')

healthConsumptionDf = pd.DataFrame(healthcomp_csv)
totalExpenditures = pd.DataFrame(total_national)
historicalHealthCare = pd.DataFrame(historical)
health_behavior = pd.DataFrame(health_habits)

# %%
health_behavior.rename(columns={"YearStart":"Start","YearEnd":"End","LocationAbbr":"State","Data_Value":"Percent Adults"},inplace=True)
clean_health_behavior = health_behavior.loc[:,["Start","End","State","Topic","Question","Percent Adults","GeoLocation"]]
clean_health_behavior.head()
# Out:
#    Start   End State                    Topic  \
# 0   2011  2011    AL  Obesity / Weight Status
# 1   2011  2011    AL  Obesity / Weight Status
# 2   2011  2011    AL  Obesity / Weight Status
# 3   2011  2011    AL  Obesity / Weight Status
# 4   2011  2011    AL  Obesity / Weight Status
#
#                                             Question  Percent Adults  \
# 0  Percent of adults aged 18 years and older who ...            32.0
# 1  Percent of adults aged 18 years and older who ...            32.3
# 2  Percent of adults aged 18 years and older who ...            31.8
# 3  Percent of adults aged 18 years and older who ...            33.6
# 4  Percent of adults aged 18 years and older who ...            32.8
#
#                                GeoLocation
# 0  (32.84057112200048, -86.63186076199969)
# 1  (32.84057112200048, -86.63186076199969)
# 2  (32.84057112200048, -86.63186076199969)
# 3  (32.84057112200048, -86.63186076199969)
# 4  (32.84057112200048, -86.63186076199969)

# %%
healthbehavior_by_state = clean_health_behavior.groupby("State")
healthbehavior_by_state.head()
# Out:
#        Start   End State                    Topic  \
# 0       2011  2011    AL  Obesity / Weight Status
# 1       2011  2011    AL  Obesity / Weight Status
# 2       2011  2011    AL  Obesity / Weight Status
# 3       2011  2011    AL  Obesity / Weight Status
# 4       2011  2011    AL  Obesity / Weight Status
# ...      ...   ...   ...                      ...
# 48881   2016  2016    VI  Obesity / Weight Status
# 50294   2016  2016    VI  Obesity / Weight Status
# 50295   2016  2016    VI  Obesity / Weight Status
# 50296   2016  2016    VI  Obesity / Weight Status
# 50297   2016  2016    VI  Obesity / Weight Status
#
#                                                 Question  Percent Adults  \
# 0      Percent of adults aged 18 years and older who ...            32.0
# 1      Percent of adults aged 18 years and older who ...            32.3
# 2      Percent of adults aged 18 years and older who ...            31.8
# 3      Percent of adults aged 18 years and older who ...            33.6
# 4      Percent of adults aged 18 years and older who ...            32.8
# ...                                                  ...             ...
# 48881  Percent of adults aged 18 years and older who ...            32.7
# 50294  Percent of adults aged 18 years and older who ...            31.9
# 50295  Percent of adults aged 18 years and older who ...            33.4
# 50296  Percent of adults aged 18 years and older who ...            34.8
# 50297  Percent of adults aged 18 years and older who ...            27.7
#
#                                    GeoLocation
# 0      (32.84057112200048, -86.63186076199969)
# 1      (32.84057112200048, -86.63186076199969)
# 2      (32.84057112200048, -86.63186076199969)
# 3      (32.84057112200048, -86.63186076199969)
# 4      (32.84057112200048, -86.63186076199969)
# ...                                        ...
# 48881                  (18.335765, -64.896335)
# 50294                  (18.335765, -64.896335)
# 50295                  (18.335765, -64.896335)
# 50296                  (18.335765, -64.896335)
# 50297                  (18.335765, -64.896335)
#
# [275 rows x 7 columns]

# %%
healthTopic = healthbehavior_by_state.loc[]
# healthTopic
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-183d69d2f381> in <module>
# ----> 1 healthTopic = healthbehavior_by_state.loc[healthbehavior_by_state["Topic"].count() == "Obesity / Weight Status"]
#       2 # healthTopic
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     561             return self[attr]
#     562         if hasattr(self.obj, attr):
# --> 563             return self._make_wrapper(attr)
#     564
#     565         raise AttributeError(
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     602                 "using the 'apply' method".format(kind, name, type(self).__name__)
#     603             )
# --> 604             raise AttributeError(msg)
#     605
#     606         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'loc' of 'DataFrameGroupBy' objects, try using the 'apply' method
